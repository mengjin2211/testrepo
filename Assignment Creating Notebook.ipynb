# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#My-Jupyter-Notebook-on-IBM-Watson-Studio" data-toc-modified-id="My-Jupyter-Notebook-on-IBM-Watson-Studio-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>My Jupyter Notebook on IBM Watson Studio</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Create-two-sets:-x-and-y.-User-intersection()-method-to-find-the-common-items-between-set-x-and-set-y." data-toc-modified-id="Create-two-sets:-x-and-y.-User-intersection()-method-to-find-the-common-items-between-set-x-and-set-y.-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Create two sets: x and y. User intersection() method to find the common items between set x and set y.</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Jin Meng**
# Data Analytics Manager

# %% [markdown]
# *I'm interested in data science for data discovery, innovation and insight to inform decision-making and increase value.*

# %% [markdown]
# ### Create two sets: x and y. User intersection() method to find the common items between set x and set y.

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple", "IBM"}

z = x.intersection(y)

print(z)
# Out:
# {'apple'}

# %% [markdown]
# Hyperlink: <br>This is the IBM Certificate I am pursuing: https://www.coursera.org/professional-certificates/ibm-data-science<br> Table:<br>
#
# |col1  |col2  |col3  |col4  |col5  |col6  |
# |------|------|------|------|------|------|
# |data1 |data2 |data3 |data4 |data5 |data6 |<br>
# <br> This is the image of the certificate: ![Professional_Certificate_-_Data_Science.png](attachment:Professional_Certificate_-_Data_Science.png)
